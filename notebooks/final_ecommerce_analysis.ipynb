# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from scripts.load_data import load_data
from scripts.clean_data import clean_orders, clean_payments
from scripts.analysis import create_master_df, revenue_analysis
from scripts.rfm import compute_rfm
from scripts.load_processed import load_processed_master_df,load_processed_rfm

# %%
orders, customers, order_items, payments, products = load_data()

orders = clean_orders(orders)
payments = clean_payments(payments)

df = create_master_df(orders, customers, order_items, payments, products)

total_revenue, avg_order = revenue_analysis(df)

rfm = compute_rfm(df)

# %%
load_processed_master_df(df)
load_processed_rfm(rfm)
